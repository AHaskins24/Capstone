# %% [markdown]
# Percent Change in Consumer Spending, 2020-2022 CSV files

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\Percent Change in Consumer Spending, 2020-2022\Percent_Change_in_Consumer_Spending__2020-2022.csv"

# Read the CSV file into a DataFrame
data = pd.read_csv(file_path)

# Display the DataFrame
data
# Out:
#       State FIPS code        Date  All merchant category codes spending  \
# 0                 900  01/13/2020                                -0.617
# 1                2500  01/13/2020                                 0.919
# 2                3400  01/13/2020                                 0.887
# 3                3600  01/13/2020                                 0.389
# 4                4400  01/13/2020                                 2.570
# ...               ...         ...                                   ...
# 4605              900  04/30/2023                                24.200
# 4606             2500  04/30/2023                                20.600
# 4607             3400  04/30/2023                                29.900
# 4608             3600  04/30/2023                                24.600
# 4609             4400  04/30/2023                                 8.960
#
#       Accommodation and food service (ACF) spending  \
# ...

# %%
#How does the overall consumer spending change over time during the COVID period?

# Query to plot the overall consumer spending over time
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(file_path)
data['Date'] = pd.to_datetime(data['Date'])
data.plot(x='Date', y='All merchant category codes spending', kind='line')
plt.xlabel('Date')
plt.ylabel('Consumer Spending')
plt.title('Overall Consumer Spending over Time')
plt.show()
