# %% [markdown]
# e-commerce as % of Sales and digital media spend, covid spending habits
#
#         •Source: Company reports and J.P. Morgan estimates.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\covidcbjpmorgan.csv")
data.head(10)
# Out:
#   Category  Digital as % of Media Spend (RHS)  E-commerce as % of Sales
# 0     2008                                NaN                       0.7
# 1     2009                                NaN                       0.9
# 2     2010                                NaN                       1.1
# 3     2011                                8.0                       1.6
# 4     2012                               10.0                       1.9
# 5     2013                               10.4                       2.6
# 6     2014                               16.0                       3.4
# 7     2015                               25.0                       5.1
# 8     2016                               32.0                       6.4
# 9     2017                               38.0                       8.0

# %%
categories = data['Category']
ecommerce_growth = data['E-commerce as % of Sales']

colors = ['#52004e', '#5e004f', '#8f0053', '#d92654', '#dd5875', '#eec2b7', '#f1e7e4']

plt.figure(figsize=(12, 6))
plt.plot(categories, ecommerce_growth, color=colors[2], marker='o')
plt.title('E-commerce Growth over Time')
plt.ylabel('E-commerce as % of Sales')
plt.grid(True)
plt.xticks()
plt.show()
