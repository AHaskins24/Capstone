# %% [markdown]
# Indicators of Anxiety or Depression csv data

# %%
pip install matplotlib-radar
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib-radar (from versions: none)
# ERROR: No matching distribution found for matplotlib-radar

# %%
import pandas as pd
import matplotlib.pyplot as plt


# read in the data
data = pd.read_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days.csv")

# Display
data.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Phase  Time Period     Time Period Label  \
# 0  United States     1            1  Apr 23 - May 5, 2020
# 1  18 - 29 years     1            1  Apr 23 - May 5, 2020
# 2  30 - 39 years     1            1  Apr 23 - May 5, 2020
# 3  40 - 49 years     1            1  Apr 23 - May 5, 2020
# 4  50 - 59 years     1            1  Apr 23 - May 5, 2020
#
#   Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0              4/23/2020             5/5/2020   23.5    22.7     24.3
# ...

# %%
#get the column and rows names:
#column names
column_names = data.columns.tolist()

#row names
row_names = data.iloc[:, 0].tolist()

# Print
print("Column names:", column_names)
print("Row names:", row_names)
# Out:
# Column names: ['Indicator', 'Group', 'State', 'Subgroup', 'Phase', 'Time Period', 'Time Period Label', 'Time Period Start Date', 'Time Period End Date', 'Value', 'Low CI', 'High CI', 'Confidence Interval', 'Quartile Range']
# ...

# %%
unique_row_names = data['State'].unique()

print(unique_row_names)
# Out:
# ['United States' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'District of Columbia' 'Florida'
#  'Georgia' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'New York' 'North Carolina'
#  'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island'
#  'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont'
#  'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %% [markdown]
# Finding the min, max, mean and median of the states, and displaying results based on date and state

# %%
# Group the data 
indicator_means = data.groupby('Indicator')['Value'].mean()
sorted_indicators = indicator_means.sort_values(ascending=False)

# Print
print("Statistics of Sorted Indicators:")
print("-------------------------------")
print("Maximum Value: ", round(sorted_indicators.max()))
print("Minimum Value: ", round(sorted_indicators.min()))
print("Median Value: ", round(sorted_indicators.median()))
print("Mean Value: ", round(sorted_indicators.mean()))
# Out:
# Statistics of Sorted Indicators:
# -------------------------------
# Maximum Value:  35
# Minimum Value:  24
# Median Value:  30
# Mean Value:  30

# %%
max_high_ci = data['High CI'].max()

min_low_ci = data['Low CI'].min()

grouped_data = data.groupby('Indicator')['High CI'].mean()
highest_average = grouped_data.idxmax()
state_with_highest_average = data[data['Indicator'] == highest_average].iloc[0]['State']
state_with_max_high_ci = data[data['High CI'] == max_high_ci].iloc[0]['State']
state_with_min_low_ci = data[data['Low CI'] == min_low_ci].iloc[0]['State']

print("Maximum value from 'High CI' column:", max_high_ci)
print("State with highest 'High CI':", state_with_max_high_ci)
print("Minimum value from 'Low CI' column:", min_low_ci)
print("State with lowest 'Low CI':", state_with_min_low_ci)
print("Indicator with highest average High CI:", highest_average)
print("State with highest average High CI for the indicator:", state_with_highest_average)
# Out:
# Maximum value from 'High CI' column: 88.8
# State with maximum 'High CI': United States
# Minimum value from 'Low CI' column: 4.5
# State with minimum 'Low CI': United States
# Indicator with highest average High CI: Symptoms of Anxiety Disorder or Depressive Disorder
# State with highest average High CI for the indicator: United States

# %%
colors = ["#000000", "#F1E7E4", "#15003D", "#52004E", "#8F0053", "#D92654", "#FDBFB0"]

# %% [markdown]
# What are the main indicators of anxiety or depression?
#
# Visualize the frequency or severity of symptoms across different indicators to identify the most significant ones.

# %%
# Group the data by the "Indicator" column and calculate the mean value of the symptoms
indicator_means = data.groupby('Indicator')['Value'].mean()

# Sort the indicators based on their mean values in descending order
sorted_indicators = indicator_means.sort_values(ascending=False)

# Define the custom color palette
colors = ["#15003D", "#52004E", "#8F0053", "#D92654", "#FDBFB0"]

# Create the figure and axes
fig, ax = plt.subplots()

# Plot the horizontal bar chart with the custom color palette
ax.barh(sorted_indicators.index, sorted_indicators, color=colors)

# Set the axis labels and title
ax.set_title('Depression and Anxiety during Covid')

# Show the chart
plt.show()

# %% [markdown]
# Difference in Anxiety and Depression over Time

# %%
# Filter the data for the desired 'Indicator'
indicator_data = data[data['Indicator'] == 'Symptoms of Depressive Disorder'].copy()
indicator_data.loc[:, 'Time Period Start Date'] = pd.to_datetime(indicator_data['Time Period Start Date'])
indicator_data.loc[:, 'Time Period End Date'] = pd.to_datetime(indicator_data['Time Period End Date'])


sorted_data = indicator_data.sort_values('Time Period Start Date')
fig, ax = plt.subplots()


ax.plot(sorted_data['Time Period Start Date'], sorted_data['Value'], marker='o', color=colors[1])
ax.set_title('Difference in Anxiety and Depression in the time of Covid')

plt.xticks()
plt.show()
# Out:
# C:\Users\ahask\AppData\Local\Temp\ipykernel_22148\3283314596.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   indicator_data.loc[:, 'Time Period Start Date'] = pd.to_datetime(indicator_data['Time Period Start Date'])
# C:\Users\ahask\AppData\Local\Temp\ipykernel_22148\3283314596.py:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   indicator_data.loc[:, 'Time Period End Date'] = pd.to_datetime(indicator_data['Time Period End Date'])

# %% [markdown]
# Are there any significant differences in symptoms between different phases or time periods?

# %%
# Filter for the year 2020
data_2020 = data[data['Time Period Start Date'].str.contains('2020')]

# Group the data 
grouped_data = data_2020.groupby('Phase')['Value'].mean()

# Define the phases and their corresponding colors
phases = ['1', '2', '3', '4']
colors = ["#15003D", "#52004E", "#8F0053"]

#figure and axes
fig, ax = plt.subplots()
ax.bar(grouped_data.index, grouped_data, color=colors)

#charting 
ax.set_xlabel('Phase')
ax.set_ylabel('Average Value')
ax.set_title('Comparison of Symptoms between Phases (2020)')

# Display
plt.show()
