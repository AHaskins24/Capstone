# %% [markdown]
# This is the Notebook to explore the Topic of World's Happiness. The dataset is from: https://www.kaggle.com/datasets/usamabuttar/world-happiness-report-2005-present

# %%
#read in the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Read the CSV file
data = pd.read_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\World Happiness Report.csv")

# Explore the data
data.head()
# Out:
#   Country Name Regional Indicator  Year  Life Ladder  Log GDP Per Capita  \
# 0  Afghanistan         South Asia  2008     3.723590            7.350416
# 1  Afghanistan         South Asia  2009     4.401778            7.508646
# 2  Afghanistan         South Asia  2010     4.758381            7.613900
# 3  Afghanistan         South Asia  2011     3.831719            7.581259
# 4  Afghanistan         South Asia  2012     3.782938            7.660506
#
#    Social Support  Healthy Life Expectancy At Birth  \
# 0        0.450662                         50.500000
# 1        0.552308                         50.799999
# 2        0.539075                         51.099998
# 3        0.521104                         51.400002
# 4        0.520637                         51.700001
#
#    Freedom To Make Life Choices  Generosity  Perceptions Of Corruption  \
# 0                      0.718114    0.167652                   0.881686
# ...

# %%
# Find the minimum and maximum values of the 'Year' column
min_year = data['Year'].min()
max_year = data['Year'].max()


print("Minimum Year:", min_year)
print("Maximum Year:", max_year)
# Out:
# Minimum Year: 2005
# Maximum Year: 2022

# %%
# Read the CSV file
data = pd.read_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\World Happiness Report.csv")

# Calculate the average generosity by grouping the data by "Country Name"
avg_generosity = data.groupby('Country Name')['Generosity'].mean().reset_index()

# Plotting a Bar Plot of the average generosity
plt.figure(figsize=(8, 35))
plt.barh(avg_generosity['Country Name'], avg_generosity['Generosity'], color=colors)
plt.xlabel('Country')
plt.ylabel('Average Generosity')
plt.title('Average Generosity by Country')
plt.xticks(fontsize=8)  # Set fontsize to adjust the x-axis labels
plt.tight_layout()
plt.show()

# %%
import random

# Find the country with the highest and lowest generosity values for each year
max_generosity = data.groupby('Year')['Generosity'].idxmax()
min_generosity = data.groupby('Year')['Generosity'].idxmin()

# Get the country names corresponding to the highest and lowest generosity values
country_max_generosity = data.loc[max_generosity, ['Year', 'Country Name', 'Generosity']]
country_min_generosity = data.loc[min_generosity, ['Year', 'Country Name', 'Generosity']]

# Create a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
bar_width = 0.35

# Generate an array of indices for the x-axis ticks
ind = np.arange(len(country_max_generosity))

# Define the desired colors

colors = ['#000000', '#e2debc', '#dfb399', '#ba9990', '#adc4af', '#77a5a2', '#336d7c', '#083c4e']

# Plot the highest and lowest generosity values as bars with the specified colors
ax.bar(ind, country_max_generosity['Generosity'], width=bar_width, label='Highest Generosity', color='#083c4e')
ax.bar(ind + bar_width, country_min_generosity['Generosity'], width=bar_width, label='Lowest Generosity', color='#ba9990')

# Set the x-axis ticks and labels
ax.set_xticks(ind + bar_width / 2)
ax.set_xticklabels(country_max_generosity['Year'])

# Rotate x-axis labels for better readability
plt.xticks(fontsize=10)

# Set labels and title
ax.set_xlabel('Year')
ax.set_ylabel('Generosity')
ax.set_title('Highest and Lowest Generosity by Year')
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Find the country with the highest and lowest generosity values for each year
max_generosity = data.groupby('Year')['Generosity'].idxmax()
min_generosity = data.groupby('Year')['Generosity'].idxmin()

# Get the country names corresponding to the highest and lowest generosity values
country_max_generosity = data.loc[max_generosity, ['Year', 'Country Name', 'Generosity']]
country_min_generosity = data.loc[min_generosity, ['Year', 'Country Name', 'Generosity']]

# Create a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
bar_width = 0.35

# Generate an array of indices for the x-axis ticks
ind = np.arange(len(country_max_generosity))

# Define the desired colors
color_max = "#083c4e"
color_min = "#77a5a2"

# Plot the highest and lowest generosity values as bars with the specified colors
ax.bar(ind, country_max_generosity['Generosity'], width=bar_width, label='Highest Generosity', color=color_max)
ax.bar(ind + bar_width, country_min_generosity['Generosity'], width=bar_width, label='Lowest Generosity', color=color_min)

# Set the x-axis ticks and labels
ax.set_xticks(ind + bar_width / 2)
ax.set_xticklabels(country_max_generosity['Year'])

# Rotate x-axis labels for better readability
plt.xticks(fontsize=10)

# Set labels and title
ax.set_ylabel('Generosity')
ax.set_title('Highest and Lowest Generosity by Year')
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Group the data by "Country Name" and find the maximum and minimum generosity values
max_generosity = data.groupby('Country Name')['Generosity'].max().reset_index()
min_generosity = data.groupby('Country Name')['Generosity'].min().reset_index()

# Display the maximum and minimum generosity values per country
print("Maximum Generosity:")
print(max_generosity)
print("\nMinimum Generosity:")
print(min_generosity)
# Out:
# Maximum Generosity:
#     Country Name  Generosity
# 0    Afghanistan    0.237588
# 1        Albania    0.041378
# 2        Algeria    0.000268
# 3         Angola    0.052619
# 4      Argentina   -0.012197
# ..           ...         ...
# 160    Venezuela    0.128371
# 161      Vietnam    0.182484
# 162        Yemen    0.009045
# 163       Zambia    0.141230
# 164     Zimbabwe    0.006313
#
# [165 rows x 2 columns]
#
# Minimum Generosity:
#     Country Name  Generosity
# 0    Afghanistan   -0.119410
# 1        Albania   -0.206186
# 2        Algeria   -0.209753
# 3         Angola   -0.170031
# 4      Argentina   -0.214477
# ..           ...         ...
# 160    Venezuela   -0.232479
# 161      Vietnam   -0.178987
# 162        Yemen   -0.175701
# 163       Zambia   -0.104995
# 164     Zimbabwe   -0.107365
#
# [165 rows x 2 columns]

# %%
# Group the data by "Country Name" and find the maximum and minimum generosity values
max_generosity = data.groupby('Country Name')['Generosity'].max().reset_index()
min_generosity = data.groupby('Country Name')['Generosity'].min().reset_index()

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 40))

# Plot the maximum and minimum generosity values
ax.barh(max_generosity['Country Name'], max_generosity['Generosity'], label='Maximum Generosity', color='#dfb399')
ax.barh(min_generosity['Country Name'], min_generosity['Generosity'], label='Minimum Generosity', color='#336d7c')

# Set labels and title
ax.set_xlabel('Generosity')
ax.set_title('How Generous is your Country?')
ax.legend()

# Rotate x-axis labels for better readability
plt.xticks(fontsize=10)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the average generosity by grouping the data by "Country Name"
avg_generosity = data.groupby('Country Name')['Generosity'].mean().reset_index()

# Find the country with the highest average generosity
highest_avg_generosity_row = avg_generosity.loc[avg_generosity['Generosity'].idxmax()]
highest_avg_generosity_country = highest_avg_generosity_row['Country Name']
highest_avg_generosity_value = highest_avg_generosity_row['Generosity']

# Print the country with the highest average generosity and its value
print("Country with the highest average generosity:", highest_avg_generosity_country)
print("Average generosity value:", highest_avg_generosity_value)
# Out:
# Country with the highest average generosity: Myanmar
# Average generosity value: 0.6119923709

# %%
# Calculate the average generosity by grouping the data by "Country Name"
avg_generosity = data.groupby('Country Name')['Generosity'].mean().reset_index()

# Find the country with the lowest average generosity
lowest_avg_generosity_row = avg_generosity.loc[avg_generosity['Generosity'].idxmin()]
lowest_avg_generosity_country = lowest_avg_generosity_row['Country Name']
lowest_avg_generosity_value = lowest_avg_generosity_row['Generosity']

# Print the country with the lowest average generosity and its value
print("Country with the lowest average generosity:", lowest_avg_generosity_country)
print("Average generosity value:", lowest_avg_generosity_value)
# Out:
# Country with the lowest average generosity: Greece
# Average generosity value: -0.2778751929333333

# %%
# Filter the data for rows with "United States" in the "Country Name" column
us_data = data[data['Country Name'] == 'United States']

# Display the filtered data
us_data
# Out:
#        Country Name     Regional Indicator  Year  Life Ladder  \
# 2071  United States  North America and ANZ  2006     7.181794
# 2072  United States  North America and ANZ  2007     7.512688
# 2073  United States  North America and ANZ  2008     7.280386
# 2074  United States  North America and ANZ  2009     7.158032
# 2075  United States  North America and ANZ  2010     7.163616
# 2076  United States  North America and ANZ  2011     7.115139
# 2077  United States  North America and ANZ  2012     7.026227
# 2078  United States  North America and ANZ  2013     7.249285
# 2079  United States  North America and ANZ  2014     7.151114
# 2080  United States  North America and ANZ  2015     6.863947
# 2081  United States  North America and ANZ  2016     6.803600
# 2082  United States  North America and ANZ  2017     6.991759
# 2083  United States  North America and ANZ  2018     6.882685
# 2084  United States  North America and ANZ  2019     6.943701
# ...

# %%
# Count the number of unique 'Country Name'
num_countries = data['Country Name'].nunique()
print("Number of Participants for USA:", num_countries)
# Out:
# Number of Participants for USA: 165

# %%
# Filter the data for rows with "United States" in the "Country Name" column
us_data = data[data['Country Name'] == 'United States']


freedom = us_data.groupby('Year')['Freedom To Make Life Choices'].sum()  

print(freedom)
# Out:
# Year
# 2006    0.911496
# 2007    0.871904
# 2008    0.877956
# 2009    0.830684
# 2010    0.828044
# 2011    0.863202
# 2012    0.822662
# 2013    0.792256
# 2014    0.866077
# 2015    0.848753
# 2016    0.757893
# 2017    0.868497
# 2018    0.824607
# 2019    0.836139
# 2020    0.850447
# 2021    0.815735
# 2022    0.735640
# Name: Freedom To Make Life Choices, dtype: float64

# %%
# Filter the data for rows with "United States" in the "Country Name" column
us_data = data[data['Country Name'] == 'United States']


generosity_per_year = us_data.groupby('Year')['Generosity'].sum()  

print(generosity_per_year)
# Out:
# Year
# 2006    0.000000
# 2007    0.192796
# 2008    0.250227
# 2009    0.196253
# 2010    0.239416
# 2011    0.156178
# 2012    0.210162
# 2013    0.269373
# 2014    0.216904
# 2015    0.215132
# 2016    0.139648
# 2017    0.192888
# 2018    0.111657
# 2019    0.139838
# 2020    0.029317
# 2021    0.190033
# 2022    0.190581
# Name: Generosity, dtype: float64

# %%
import matplotlib.pyplot as plt

# Define the custom color palette
colors = ["#000000", "#F1E7E4", "#15003D", "#52004E", "#8F0053", "#D92654", "#FDBFB0"]

# %%
columns_of_interest = ['Year', 'Log GDP Per Capita', 'Social Support', 'Freedom To Make Life Choices',
                       'Perceptions Of Corruption', 'Confidence In National Government']

# Set up the color palette
colors = ['#ba9990', '#adc4af', '#77a5a2', '#336d7c', '#083c4e', '#062e3b']

# Plotting
plt.figure(figsize=(12, 6))
for i, column in enumerate(columns_of_interest[1:]):
    plt.plot(us_data['Year'], us_data[column], color=colors[i % len(colors)], label=column)


plt.ylabel('Confidence Level')
plt.title('Comparison of Confidence Over Time (United States)')
plt.legend()
plt.show()

# %%
# Plotting a Line Plot
plt.plot(us_data['Year'], us_data['Generosity'] , color='#083c4e')
plt.ylabel('Generosity')
plt.title('Generosity Over Time (United States)')
plt.show()

# %%
# Define the custom color palette
colors = ['#fefefd', '#e2debc', '#dfb399', '#ba9990', '#adc4af', '#77a5a2', '#336d7c', '#083c4e', '#062e3b']

# Plotting a Bar Plot with custom color palette
plt.bar(us_data['Year'], us_data['Generosity'], color=colors)
plt.xlabel('Year')
plt.ylabel('Generosity')
plt.title('Generosity Over Time (United States)')
plt.show()
