# %% [markdown]
# COVID-19 Case Surveillance Public Use Data csv files

# %%
import pandas as pd

file_path = r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\COVID-19 Case Surveillance Public Use Data\COVID-19_Case_Surveillance_Public_Use_Data.csv"

# Read the CSV file into a DataFrame
data = pd.read_csv(file_path)

# Display the DataFrame
data
# Out:
#                   cdc_case_earliest_dt  cdc_report_dt pos_spec_dt    onset_dt  \
# 0                            2022/12/28    2023/01/04  2022/12/28         NaN
# 1                            2020/11/15    2021/12/06  2020/11/15         NaN
# 2                            2022/01/09    2022/01/18  2022/01/15  2022/01/09
# 3                            2022/11/02    2022/11/09  2022/11/02  2022/11/02
# 4                            2022/02/01    2022/02/10  2022/02/01  2022/02/01
# ...                                 ...           ...         ...         ...
# 4269454                      2022/01/13    2022/09/23         NaN         NaN
# 4269455                  "error" : true           NaN         NaN         NaN
# 4269456    "message" : "Internal error"           NaN         NaN         NaN
# 4269457                  "status" : 500           NaN         NaN         NaN
# 4269458                               }           NaN         NaN         NaN
#
# ...

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\COVID-19 Case Surveillance Public Use Data\COVID-19_Case_Surveillance_Public_Use_Data.csv")

# Perform data cleaning or manipulation Remove rows with missing values
cleaned_data = data.dropna()

# Write the cleaned data back to a new CSV file
cleaned_data.to_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\COVID-19 Case Surveillance Public Use Data\cleaned_data.csv", index=False)

# %%
# Read the CSV file
data = pd.read_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\COVID-19 Case Surveillance Public Use Data\COVID-19_Case_Surveillance_Public_Use_Data.csv")

# Perform data cleaning or manipulation
# Example: Remove rows with missing values
cleaned_data = data.dropna()

# Display the head of the cleaned data
print(cleaned_data.head())
# Out:
#   cdc_case_earliest_dt  cdc_report_dt pos_spec_dt    onset_dt  \
# 2            2022/01/09    2022/01/18  2022/01/15  2022/01/09
# 3            2022/11/02    2022/11/09  2022/11/02  2022/11/02
# 4            2022/02/01    2022/02/10  2022/02/01  2022/02/01
# 5            2020/12/30    2021/05/22  2020/12/30  2020/12/30
# 8            2022/08/26    2022/09/07  2022/08/26  2022/08/26
#
#               current_status   sex      age_group race_ethnicity_combined  \
# 2  Laboratory-confirmed case  Male  70 - 79 Years     Black, Non-Hispanic
# 3              Probable Case  Male  70 - 79 Years     Black, Non-Hispanic
# 4  Laboratory-confirmed case  Male  70 - 79 Years     Black, Non-Hispanic
# 5  Laboratory-confirmed case  Male  70 - 79 Years     Black, Non-Hispanic
# 8  Laboratory-confirmed case  Male  70 - 79 Years     Black, Non-Hispanic
#
#    hosp_yn   icu_yn death_yn medcond_yn
# 2       No  Unknown       No    Unknown
# 3  Unknown  Unknown  Unknown    Unknown
# ...

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv(r"C:\Users\ahask\Documents\DA8\Capstone\Capstone\Data\COVID-19 Case Surveillance Public Use Data\COVID-19_Case_Surveillance_Public_Use_Data.csv")

# Perform data cleaning or manipulation Remove rows with missing values
cleaned_data = data.dropna()

# Print the column names of the cleaned data
cleaned_data.columns
# Out:
# Index(['cdc_case_earliest_dt ', 'cdc_report_dt', 'pos_spec_dt', 'onset_dt',
#        'current_status', 'sex', 'age_group', 'race_ethnicity_combined',
#        'hosp_yn', 'icu_yn', 'death_yn', 'medcond_yn'],
#       dtype='object')
